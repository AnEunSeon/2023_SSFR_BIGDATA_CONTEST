# %%
import numpy as np
import pandas as pd

# %%
df=pd.concat([df1,df2,df3],axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 267777 entries, 0 to 59233
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ZCPRLCLCD      267777 non-null  object
#  1   ZINSRDAVL      267777 non-null  int64
#  2   ZIOSEXCD       267777 non-null  int64
#  3   ZDPRODSCD      267584 non-null  float64
#  4   NCR            267777 non-null  object
#  5   ZCARPSGVL      267777 non-null  object
#  6   차종             267777 non-null  object
#  7   ZDRVLISCD      267777 non-null  int64
#  8   ZDRVLISCD___T  267777 non-null  object
#  9   ZENTCARCD      267777 non-null  int64
#  10  ZCARISDAM      267777 non-null  object
#  11  ZIMAGERVL      267777 non-null  object
#  12  마일리지약정거리       267777 non-null  object
#  13  YUHO           267777 non-null  int64
#  14  SAGO           267777 non-null  int64
# dtypes: float64(1), int64(6), object(8)
# memory usage: 32.7+ MB

# %% [markdown]
# 변수 설명
# - ZCPRLCLCD : 상품대분류
# - ZINSRDAVL : 피보험자연령대
# - ZIOSEXCD : 피보험자성별코드
# - ZDPRODSCD : 국산구분코드
# - NCR : 직전 3년간 사고건수
# - ZCARPSGVL : 차량경과년수
# - 차종: 배기량별 차종분류
# - ZDRVLISCD : 운전자한정특별약관코드
# - ZDRVLISCD___T : 운전자한정특별약관
# - ZENTCARCD : 가입경력코드
# - ZCARISDAM : 차량가입금액
# - ZIMAGERVL : 블랙박스특별요율
# - YUHO : 유효대수
# - SAGO : 사고건수

# %%
#분석에 의미 없는 변수(열) 제거 
df=df.drop(['ZCPRLCLCD','ZDRVLISCD___T'],axis=1)

# %%
#유효대수가 0인 관측치 제거 (사고율 계산이 불가하기 때문)
df=df[df['YUHO']!=0]

# %%
#결측치 확인
df.isnull().sum()
# Out:
# ZINSRDAVL     0
# ZIOSEXCD      0
# ZDPRODSCD    11
# NCR           0
# ZCARPSGVL     0
# 차종            0
# ZDRVLISCD     0
# ZENTCARCD     0
# ZCARISDAM     0
# ZIMAGERVL     0
# 마일리지약정거리      0
# YUHO          0
# SAGO          0
# dtype: int64

# %%
#결측치 제거
df=df.dropna(subset=['ZDPRODSCD'])

# %%
#피보험자연령대가 0~10, 90~100대인 관측치 제거 (이상치로 판단)
df=df[(df['ZINSRDAVL']!=0)&(df['ZINSRDAVL']!=10)&(df['ZINSRDAVL']!=90)&(df['ZINSRDAVL']!=100)]

# %%
#변수설명테이블에 정의되지 않은 값을 가진 관측치 제거 
df=df[df['NCR']!='0']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167610 entries, 134 to 59233
# Data columns (total 13 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ZINSRDAVL  167610 non-null  int64
#  1   ZIOSEXCD   167610 non-null  int64
#  2   ZDPRODSCD  167610 non-null  float64
#  3   NCR        167610 non-null  object
#  4   ZCARPSGVL  167610 non-null  object
#  5   차종         167610 non-null  object
#  6   ZDRVLISCD  167610 non-null  int64
#  7   ZENTCARCD  167610 non-null  int64
#  8   ZCARISDAM  167610 non-null  object
#  9   ZIMAGERVL  167610 non-null  object
#  10  마일리지약정거리   167610 non-null  object
#  11  YUHO       167610 non-null  int64
#  12  SAGO       167610 non-null  int64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 17.9+ MB

# %%
df.head()
# Out:
#      ZINSRDAVL  ZIOSEXCD  ZDPRODSCD NCR ZCARPSGVL     차종  ZDRVLISCD  \
# 134         20         1        1.0   B     10년이하  다목적2종          2
# 138         20         1        1.0   B     10년이상    소형B          4
# 142         20         1        1.0   B      5년이하    소형B          3
# 150         20         1        1.0   B     10년이하    소형B          1
# 159         20         1        1.0   B      5년이하     중형          1
#
#      ZENTCARCD ZCARISDAM ZIMAGERVL 마일리지약정거리  YUHO  SAGO
# 134          7       미가입       미가입   12000K     1     1
# 138          3       미가입        가입   15000K     1     0
# 142          4    5천만원이하        가입   15000K     1     0
# 150          6    5천만원이하        가입      미가입     1     2
# 159          3    5천만원이하        가입   15000K     1     0

# %%
#순서형 범주형 자료에 대한 Label Encoding 진행
ord_map1={20:2,30:3,40:4,50:5,60:6,70:7,80:8}
df['ZINSRDAVL']=df['ZINSRDAVL'].map(ord_map1)

ord_map2={'소형A':1,'소형B':2,'중형':3,'대형':4,'다목적1종':5,'다목적2종':5}
df['차종']=df['차종'].map(ord_map2)

ord_map3={'미가입':1,'5천만원이하':2,'1억이하':3,'1억이상':4}
df['ZCARISDAM']=df['ZCARISDAM'].map(ord_map3)

ord_map4={'미가입':1,'3000K':2,'5000K':3,'7000K':4,'10000K':5,'12000K':6,'15000K':7}
df['마일리지약정거리']=df['마일리지약정거리'].map(ord_map4)

ord_map5={'신차':1,'5년이하':2,'10년이하':3,'10년이상':4}
df['ZCARPSGVL']=df['ZCARPSGVL'].map(ord_map5)

# %%
#이진형 범주형 자료에 대한 Encoding 진행 
#기존 데이터에서 범위가 (1,2)였던 것을 (0,1)으로 변경
df['ZIOSEXCD']=df['ZIOSEXCD']-1
df['ZDPRODSCD']=df['ZDPRODSCD']-1
bin_map={'미가입':0,'가입':1}
df['ZIMAGERVL']=df['ZIMAGERVL'].map(bin_map)

# %%
#가독성을 위해 직전3년사고건수의 값을 mapping
ncr_map={'N':1,'D':2,'C':3,'B':4,'Z':5}
df['NCR']=df['NCR'].map(ncr_map)

# %%
df['ZDPRODSCD']=df['ZDPRODSCD'].astype(int)

# %%
df.head()
# Out:
#      ZINSRDAVL  ZIOSEXCD  ZDPRODSCD  NCR  ZCARPSGVL  차종  ZDRVLISCD  ZENTCARCD  \
# 134          2         0          0    4          3   5          2          7
# 138          2         0          0    4          4   2          4          3
# 142          2         0          0    4          2   2          3          4
# 150          2         0          0    4          3   2          1          6
# 159          2         0          0    4          2   3          1          3
#
#      ZCARISDAM  ZIMAGERVL  마일리지약정거리  YUHO  SAGO
# 134          1          0         6     1     1
# 138          1          1         7     1     0
# 142          2          1         7     1     0
# 150          2          1         1     1     2
# 159          2          1         7     1     0

# %%
#파생변수 생성
df['마일리지할인율_가입여부']=0
df.loc[df['마일리지약정거리']!=1,'마일리지할인율_가입여부']=1

df['자차보험_가입여부']=0
df.loc[df['ZCARISDAM']!=1,'자차보험_가입여부']=1

df['고경력운전자']=0
df.loc[df['ZCARISDAM']==8,'고경력운전자']=1

df['저경력운전자']=0
df.loc[df['ZCARISDAM']==1,'저경력운전자']=1

# %%
#모델링의 종속변수로 사용할 사고율 계산
df['사고율']=df['SAGO']/df['YUHO']

# %%
df.head()
# Out:
#      ZINSRDAVL  ZIOSEXCD  ZDPRODSCD  NCR  ZCARPSGVL  차종  ZDRVLISCD  ZENTCARCD  \
# 134          2         0          0    4          3   5          2          7
# 138          2         0          0    4          4   2          4          3
# 142          2         0          0    4          2   2          3          4
# 150          2         0          0    4          3   2          1          6
# 159          2         0          0    4          2   3          1          3
#
#      ZCARISDAM  ZIMAGERVL  마일리지약정거리  YUHO  SAGO  마일리지할인율_가입여부  자차보험_가입여부  \
# 134          1          0         6     1     1             1          0
# 138          1          1         7     1     0             1          0
# 142          2          1         7     1     0             1          1
# 150          2          1         1     1     2             0          1
# 159          2          1         7     1     0             1          1
#
#      고경력운전자  저경력운전자  사고율
# 134       0       1  1.0
# 138       0       1  0.0
# 142       0       0  0.0
# 150       0       0  2.0
# 159       0       0  0.0

# %%
#편의를 위해 Column명 변경
df.columns=['피보험자연령대','피보험자성별','국산구분','직전3년간사고건수','차량경과년수','차종','운전자한정특별약관','가입경력','차량가입금액','영상기록장치특약','마일리지약정거리','유효대수','사고건수','마일리지약정_가입여부','자차보험_가입여부','고경력운전자','저경력운전자','사고율']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167610 entries, 134 to 59233
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   피보험자연령대    167610 non-null  int64
#  1   직전3년간사고건수  167610 non-null  int64
#  2   차량경과년수     167610 non-null  int64
#  3   차종         167610 non-null  int64
#  4   가입경력       167610 non-null  int64
#  5   차량가입금액     167610 non-null  int64
#  6   마일리지약정거리   167610 non-null  int64
# dtypes: int64(7)
# memory usage: 10.2 MB

# %%
df.to_csv('dataset.csv',index=False,encoding='cp949')
