# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df=pd.read_csv('C:/Users/EunSeon/Downloads/dataset.csv')

# %%
#순서형과 명목형 범주 관계에 대해 상관계수를 파악할 수 있는 방법이 없기 때문에 명목형 범주형 자료 제거
df.drop(['피보험자성별','국산구분','운전자한정특별약관','영상기록장치특약','유효대수','사고건수','마일리지약정_가입여부','자차보험_가입여부','고경력운전자','저경력운전자','사고율'],axis=1,inplace=True)

# %%
#기타를 의미하는 범주 제거
df=df[df['직전3년간사고건수']!=5]

# %%
df.corr(method='spearman',min_periods=1)
# Out:
#             피보험자연령대  직전3년간사고건수    차량경과년수        차종      가입경력    차량가입금액  \
# 피보험자연령대    1.000000   0.041802  0.048243  0.092679  0.423886 -0.012029
# 직전3년간사고건수  0.041802   1.000000  0.035347 -0.006821  0.135790 -0.017705
# 차량경과년수     0.048243   0.035347  1.000000 -0.040790  0.004131 -0.378711
# 차종         0.092679  -0.006821 -0.040790  1.000000  0.087870  0.131210
# 가입경력       0.423886   0.135790  0.004131  0.087870  1.000000 -0.004308
# 차량가입금액    -0.012029  -0.017705 -0.378711  0.131210 -0.004308  1.000000
# 마일리지약정거리   0.000935   0.000898 -0.005280 -0.031121 -0.073971  0.033376
#
#            마일리지약정거리
# 피보험자연령대    0.000935
# 직전3년간사고건수  0.000898
# 차량경과년수    -0.005280
# 차종        -0.031121
# 가입경력      -0.073971
# 차량가입금액     0.033376
# 마일리지약정거리   1.000000

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
sns.heatmap(data=df.corr(method='spearman'),annot=True,linewidths=.5,cmap='Blues')
# Out:
# <Axes: >
